# %% [markdown]
# <a href="https://colab.research.google.com/github/William624-stack/DB/blob/main/Banco%20de%20Dados%20_Carros_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2-1028141915.py in <cell line: 0>()
# ----> 1 s
#
# NameError: name 's' is not defined

# %% [markdown]
# Trabalhando com Dados
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.set_option.html

# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv('https://raw.githubusercontent.com/daniel-usp/LIT/master/db.csv' , sep = ';')

# %%
dataset['Valor'][0:2]   # Foi capturado as duas linhas
# Out:
# 0     88078.64
# 1    106161.94
# Name: Valor, dtype: float64

# %%
vendas = [10,20,30]
vendas = pd.Series(vendas)
vendas.mean()
# Out:
# np.float64(20.0)

# %% [markdown]
# Estrutura de Dados

# %%
import pandas as pd

# %% [markdown]
# Criando uma Series a partir de uma lista

# %%
carros = ['Jetta Variant', 'Passat', 'Crossfox']
type(carros)
# Out:
# list

# %%
pd.Series(carros)
# Out:
# 0    Jetta Variant
# 1           Passat
# 2         Crossfox
# dtype: object

# %%
vendas = [{'Daniel': 20000, 'Gabriel': 15000, 'Ana': 60000} ,10, 'varejo']    # {} Caracteriza um Dicionário
vendas
# Out:
# [{'Daniel': 20000, 'Gabriel': 15000, 'Ana': 60000}, 10, 'varejo']

# %%
dados = [{'Nome':'Jetta Variant', 'Motor': 'Motor 4.0 Turbo', 'Ano': 2003, 'Quilometragem': 44410.0, 'Zero_km':False, 'Valor': 88078.64}]
dados
# Out:
# [{'Nome': 'Jetta Variant',
#   'Motor': 'Motor 4.0 Turbo',
#   'Ano': 2003,
#   'Quilometragem': 44410.0,
#   'Zero_km': False,
#   'Valor': 88078.64}]

# %%
df = pd.DataFrame (dados)
df
# Out:
#             Nome            Motor   Ano  Quilometragem  Zero_km     Valor
# 0  Jetta Variant  Motor 4.0 Turbo  2003        44410.0    False  88078.64

# %%
dados = {
    'Nome':['Jetta Variant', 'Passat', 'Crossfox'],
    'Motor': ['Motor 4.0 Turbo','Motor Diesel', 'Motor Diesel V8'],
    'Ano': [2003,1991,1990],
    'Quilometragem': [44410.0, 5712.0, 37123.0],
    'Zero_km': [False, False, False,],
    'Valor' : [88078.64, 106161.94, 72832.16]
}

# %%
  df2 = pd.DataFrame(dados)
  df2
# Out:
#             Nome            Motor   Ano  Quilometragem  Zero_km      Valor
# 0  Jetta Variant  Motor 4.0 Turbo  2003        44410.0    False   88078.64
# 1         Passat     Motor Diesel  1991         5712.0    False  106161.94
# 2       Crossfox  Motor Diesel V8  1990        37123.0    False   72832.16

# %% [markdown]
# Seleções com DataFrames

# %%
dataset = pd.read_csv('https://raw.githubusercontent.com/daniel-usp/LIT/master/db.csv' , sep = ';')

# %% [markdown]
# Trabalhando com Dados
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.set_option.html

# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv('https://raw.githubusercontent.com/daniel-usp/LIT/master/db.csv' , sep = ';')

# %%
dataset.head()
# Out:
#                Nome            Motor   Ano  Quilometragem  Zero_km  \
# 0     Jetta Variant  Motor 4.0 Turbo  2003        44410.0    False
# 1            Passat     Motor Diesel  1991         5712.0    False
# 2          Crossfox  Motor Diesel V8  1990        37123.0    False
# 3               DS5  Motor 2.4 Turbo  2019            NaN     True
# 4  Aston Martin DB4  Motor 2.4 Turbo  2006        25757.0    False
#
#                                           Acessórios      Valor
# 0  ['Rodas de liga', 'Travas elétricas', 'Piloto ...   88078.64
# 1  ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94
# 2  ['Piloto automático', 'Controle de estabilidad...   72832.16
# 3  ['Travas elétricas', '4 X 4', 'Vidros elétrico...  124549.07
# 4  ['Rodas de liga', '4 X 4', 'Central multimídia...   92612.10

# %%
dataset.head()
# Out:
#                Nome            Motor   Ano  Quilometragem  Zero_km  \
# 0     Jetta Variant  Motor 4.0 Turbo  2003        44410.0    False
# 1            Passat     Motor Diesel  1991         5712.0    False
# 2          Crossfox  Motor Diesel V8  1990        37123.0    False
# 3               DS5  Motor 2.4 Turbo  2019            NaN     True
# 4  Aston Martin DB4  Motor 2.4 Turbo  2006        25757.0    False
#
#                                           Acessórios      Valor
# 0  ['Rodas de liga', 'Travas elétricas', 'Piloto ...   88078.64
# 1  ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94
# 2  ['Piloto automático', 'Controle de estabilidad...   72832.16
# 3  ['Travas elétricas', '4 X 4', 'Vidros elétrico...  124549.07
# 4  ['Rodas de liga', '4 X 4', 'Central multimídia...   92612.10

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 258 entries, 0 to 257
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Nome           258 non-null    object
#  1   Motor          258 non-null    object
#  2   Ano            258 non-null    int64
#  3   Quilometragem  197 non-null    float64
#  4   Zero_km        258 non-null    bool
#  5   Acessórios     258 non-null    object
#  6   Valor          258 non-null    float64
# dtypes: bool(1), float64(2), int64(1), object(3)
# memory usage: 12.5+ KB

# %%
filtro = [dataset.columns[5], dataset.columns [6]]
subset = dataset[filtro]
subset
# Out:
#                                             Acessórios      Valor
# 0    ['Rodas de liga', 'Travas elétricas', 'Piloto ...   88078.64
# 1    ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94
# 2    ['Piloto automático', 'Controle de estabilidad...   72832.16
# 3    ['Travas elétricas', '4 X 4', 'Vidros elétrico...  124549.07
# 4    ['Rodas de liga', '4 X 4', 'Central multimídia...   92612.10
# ..                                                 ...        ...
# 253  ['Controle de estabilidade', 'Piloto automátic...   51759.58
# 254  ['Bancos de couro', 'Painel digital', 'Sensor ...   51667.06
# 255  ['Rodas de liga', 'Controle de tração', 'Câmbi...   68934.03
# 256  ['Ar condicionado', '4 X 4', 'Câmbio automátic...  122110.90
# 257  ['Central multimídia', 'Teto panorâmico', 'Vid...   90381.47
#
# [258 rows x 2 columns]

# %%
dataset.columns
# Out:
# Index(['Nome', 'Motor', 'Ano', 'Quilometragem', 'Zero_km', 'Acessórios',
#        'Valor'],
#       dtype='object')

# %%
pd.DataFrame(dataset['Valor'])
# Out:
#          Valor
# 0     88078.64
# 1    106161.94
# 2     72832.16
# 3    124549.07
# 4     92612.10
# ..         ...
# 253   51759.58
# 254   51667.06
# 255   68934.03
# 256  122110.90
# 257   90381.47
#
# [258 rows x 1 columns]

# %%
type(dataset[["Valor"]])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Selecionando Colunas

# %%
dataset[["Valor"]]
# Out:
#          Valor
# 0     88078.64
# 1    106161.94
# 2     72832.16
# 3    124549.07
# 4     92612.10
# ..         ...
# 253   51759.58
# 254   51667.06
# 255   68934.03
# 256  122110.90
# 257   90381.47
#
# [258 rows x 1 columns]

# %% [markdown]
# Agora selecionando Linha s e Colunas

# %% [markdown]
# Selecionando Linhas e Colunas - [ i : j]

# %%
dataset[0:3]
# Out:
#             Nome            Motor   Ano  Quilometragem  Zero_km  \
# 0  Jetta Variant  Motor 4.0 Turbo  2003        44410.0    False
# 1         Passat     Motor Diesel  1991         5712.0    False
# 2       Crossfox  Motor Diesel V8  1990        37123.0    False
#
#                                           Acessórios      Valor
# 0  ['Rodas de liga', 'Travas elétricas', 'Piloto ...   88078.64
# 1  ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94
# 2  ['Piloto automático', 'Controle de estabilidad...   72832.16

# %%
dataset.head(5)
# Out:
#                Nome            Motor   Ano  Quilometragem  Zero_km  \
# 0     Jetta Variant  Motor 4.0 Turbo  2003        44410.0    False
# 1            Passat     Motor Diesel  1991         5712.0    False
# 2          Crossfox  Motor Diesel V8  1990        37123.0    False
# 3               DS5  Motor 2.4 Turbo  2019            NaN     True
# 4  Aston Martin DB4  Motor 2.4 Turbo  2006        25757.0    False
#
#                                           Acessórios      Valor
# 0  ['Rodas de liga', 'Travas elétricas', 'Piloto ...   88078.64
# 1  ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94
# 2  ['Piloto automático', 'Controle de estabilidad...   72832.16
# 3  ['Travas elétricas', '4 X 4', 'Vidros elétrico...  124549.07
# 4  ['Rodas de liga', '4 X 4', 'Central multimídia...   92612.10

# %% [markdown]
# Utilizando .loc para seleções
#
# Observações: Seleciona um grupo de linhas e colunas segundo os rótulos ou uma matriz booleana.

# %%
loc = [[linhas];[colunas]]
# Out:
#   File "/tmp/ipython-input-26-596985902.py", line 1
#     loc = [[linhas];[colunas]]
#                    ^
# SyntaxError: invalid syntax

# %%
dataset = pd.read_csv('https://raw.githubusercontent.com/daniel-usp/LIT/master/db.csv' , sep = ';', index_col =  'Nome')
dataset
# Out:
#                                        Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Jetta Variant                Motor 4.0 Turbo  2003        44410.0    False
# Passat                          Motor Diesel  1991         5712.0    False
# Crossfox                     Motor Diesel V8  1990        37123.0    False
# DS5                          Motor 2.4 Turbo  2019            NaN     True
# Aston Martin DB4             Motor 2.4 Turbo  2006        25757.0    False
# ...                                      ...   ...            ...      ...
# Phantom 2013                        Motor V8  2014        27505.0    False
# Cadillac Ciel concept               Motor V8  1991        29981.0    False
# Classe GLK             Motor 5.0 V8 Bi-Turbo  2002        52637.0    False
# Aston Martin DB5                Motor Diesel  1996         7685.0    False
# Macan                        Motor Diesel V6  1992        50188.0    False
#
#                                                               Acessórios  \
# Nome
# Jetta Variant          ['Rodas de liga', 'Travas elétricas', 'Piloto ...
# Passat                 ['Central multimídia', 'Teto panorâmico', 'Fre...
# Crossfox               ['Piloto automático', 'Controle de estabilidad...
# DS5                    ['Travas elétricas', '4 X 4', 'Vidros elétrico...
# Aston Martin DB4       ['Rodas de liga', '4 X 4', 'Central multimídia...
# ...                                                                  ...
# Phantom 2013           ['Controle de estabilidade', 'Piloto automátic...
# Cadillac Ciel concept  ['Bancos de couro', 'Painel digital', 'Sensor ...
# Classe GLK             ['Rodas de liga', 'Controle de tração', 'Câmbi...
# Aston Martin DB5       ['Ar condicionado', '4 X 4', 'Câmbio automátic...
# Macan                  ['Central multimídia', 'Teto panorâmico', 'Vid...
#
#                            Valor
# Nome
# Jetta Variant           88078.64
# Passat                 106161.94
# Crossfox                72832.16
# DS5                    124549.07
# Aston Martin DB4        92612.10
# ...                          ...
# Phantom 2013            51759.58
# Cadillac Ciel concept   51667.06
# Classe GLK              68934.03
# Aston Martin DB5       122110.90
# Macan                   90381.47
#
# [258 rows x 6 columns]

# %%
dataset.loc[["Passat", "DS5"]]
# Out:
#                   Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Passat     Motor Diesel  1991         5712.0    False
# DS5     Motor 2.4 Turbo  2019            NaN     True
#
#                                                Acessórios      Valor
# Nome
# Passat  ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94
# DS5     ['Travas elétricas', '4 X 4', 'Vidros elétrico...  124549.07

# %%
df = dataset.loc[:,["Ano"]]
df
# Out:
#                         Ano
# Nome
# Jetta Variant          2003
# Passat                 1991
# Crossfox               1990
# DS5                    2019
# Aston Martin DB4       2006
# ...                     ...
# Phantom 2013           2014
# Cadillac Ciel concept  1991
# Classe GLK             2002
# Aston Martin DB5       1996
# Macan                  1992
#
# [258 rows x 1 columns]

# %%
df = dataset.loc[:,:]

# %% [markdown]
# Utilizando .iloc para posições
#
# Obsertvação: Seleciona com base nos índices, ou seja, na posição das informações

# %%
dataset.head()
# Out:
#                             Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Jetta Variant     Motor 4.0 Turbo  2003        44410.0    False
# Passat               Motor Diesel  1991         5712.0    False
# Crossfox          Motor Diesel V8  1990        37123.0    False
# DS5               Motor 2.4 Turbo  2019            NaN     True
# Aston Martin DB4  Motor 2.4 Turbo  2006        25757.0    False
#
#                                                          Acessórios      Valor
# Nome
# Jetta Variant     ['Rodas de liga', 'Travas elétricas', 'Piloto ...   88078.64
# Passat            ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94
# Crossfox          ['Piloto automático', 'Controle de estabilidad...   72832.16
# DS5               ['Travas elétricas', '4 X 4', 'Vidros elétrico...  124549.07
# Aston Martin DB4  ['Rodas de liga', '4 X 4', 'Central multimídia...   92612.10

# %%
dataset.iloc[0:3,[4,2]]
# Out:
#                                                       Acessórios  \
# Nome
# Jetta Variant  ['Rodas de liga', 'Travas elétricas', 'Piloto ...
# Passat         ['Central multimídia', 'Teto panorâmico', 'Fre...
# Crossfox       ['Piloto automático', 'Controle de estabilidad...
#
#                Quilometragem
# Nome
# Jetta Variant        44410.0
# Passat                5712.0
# Crossfox             37123.0

# %%
dataset.iloc[[1,3],[0,5]]
# Out:
#                   Motor      Valor
# Nome
# Passat     Motor Diesel  106161.94
# DS5     Motor 2.4 Turbo  124549.07

# %% [markdown]
# ## Queries com DataFrames
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.set_option.html

# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv('https://raw.githubusercontent.com/daniel-usp/LIT/master/db.csv' , sep = ';')

# %%
dataset.head()
# Out:
#                Nome            Motor   Ano  Quilometragem  Zero_km  \
# 0     Jetta Variant  Motor 4.0 Turbo  2003        44410.0    False
# 1            Passat     Motor Diesel  1991         5712.0    False
# 2          Crossfox  Motor Diesel V8  1990        37123.0    False
# 3               DS5  Motor 2.4 Turbo  2019            NaN     True
# 4  Aston Martin DB4  Motor 2.4 Turbo  2006        25757.0    False
#
#                                           Acessórios      Valor
# 0  ['Rodas de liga', 'Travas elétricas', 'Piloto ...   88078.64
# 1  ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94
# 2  ['Piloto automático', 'Controle de estabilidad...   72832.16
# 3  ['Travas elétricas', '4 X 4', 'Vidros elétrico...  124549.07
# 4  ['Rodas de liga', '4 X 4', 'Central multimídia...   92612.10

# %%
dataset["Motor"]
# Out:
# 0            Motor 4.0 Turbo
# 1               Motor Diesel
# 2            Motor Diesel V8
# 3            Motor 2.4 Turbo
# 4            Motor 2.4 Turbo
#                ...
# 253                 Motor V8
# 254                 Motor V8
# 255    Motor 5.0 V8 Bi-Turbo
# 256             Motor Diesel
# 257          Motor Diesel V6
# Name: Motor, Length: 258, dtype: object

# %%
dataset.Motor
# Out:
# 0            Motor 4.0 Turbo
# 1               Motor Diesel
# 2            Motor Diesel V8
# 3            Motor 2.4 Turbo
# 4            Motor 2.4 Turbo
#                ...
# 253                 Motor V8
# 254                 Motor V8
# 255    Motor 5.0 V8 Bi-Turbo
# 256             Motor Diesel
# 257          Motor Diesel V6
# Name: Motor, Length: 258, dtype: object

# %%
filtro = dataset.Motor == "Motor Diesel" # == Efetua uma comparação logica. Quais são os carros que tem Motor Diesel no dataset
dataset[dataset.Motor == "Motor Diesel"]
# Out:
#                       Nome         Motor   Ano  Quilometragem  Zero_km  \
# 1                   Passat  Motor Diesel  1991         5712.0    False
# 23   Effa Hafei Picape Baú  Motor Diesel  1991       102959.0    False
# 60                 Sorento  Motor Diesel  2019            NaN     True
# 62        New Fiesta Hatch  Motor Diesel  2017       118895.0    False
# 69          Kangoo Express  Motor Diesel  2007        29132.0    False
# 74                     Fit  Motor Diesel  2013        44329.0    False
# 78             Cielo Hatch  Motor Diesel  2019            NaN     True
# 86                  Symbol  Motor Diesel  2016       117714.0    False
# 89                A4 Sedan  Motor Diesel  2002        30511.0    False
# 111               A4 Avant  Motor Diesel  2014        17357.0    False
# 119          Silver Shadow  Motor Diesel  2015        99052.0    False
# 124                  Camry  Motor Diesel  2019            NaN     True
# 145                   Clio  Motor Diesel  1990        66437.0    False
# 148       Série 3 M3 Coupé  Motor Diesel  2013        19896.0    False
# 149    Gallardo LP 560 – 4  Motor Diesel  2000       113045.0    False
# 157          Chana Utility  Motor Diesel  2009        52034.0    False
# 173            TT Roadster  Motor Diesel  1998       107392.0    False
# 189    Aston Martin Virage  Motor Diesel  2019            NaN     True
# 208                Sandero  Motor Diesel  2015        34783.0    False
# 210                    XKR  Motor Diesel  1996        85127.0    False
# 211                     X5  Motor Diesel  2002        13606.0    False
# 226           Dodge Dakota  Motor Diesel  1993        71544.0    False
# 233                 i30 CW  Motor Diesel  2015         8497.0    False
# 237           Série 7 Sedã  Motor Diesel  2019            NaN     True
# 240                    V60  Motor Diesel  2004        91840.0    False
# 256       Aston Martin DB5  Motor Diesel  1996         7685.0    False
#
#                                             Acessórios      Valor
# 1    ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94
# 23   ['Controle de estabilidade', 'Painel digital',...  125684.65
# 60   ['Sensor de chuva', 'Câmera de estacionamento'...   81399.35
# 62   ['Sensor de estacionamento', 'Travas elétricas...   66007.16
# 69   ['Bancos de couro', 'Câmbio automático', 'Pilo...  146716.91
# 74   ['Freios ABS', 'Câmera de estacionamento', 'Câ...   77836.23
# 78   ['Painel digital', 'Central multimídia', 'Câme...  145197.70
# 86   ['4 X 4', 'Piloto automático', 'Sensor crepusc...  133030.60
# 89   ['Câmera de estacionamento', '4 X 4', 'Travas ...   96369.04
# 111  ['Teto panorâmico', '4 X 4', 'Bancos de couro'...  138946.88
# 119  ['4 X 4', 'Central multimídia', 'Ar condiciona...  143568.22
# 124  ['Travas elétricas', 'Rodas de liga', 'Sensor ...  138597.27
# 145  ['4 X 4', 'Câmbio automático', 'Freios ABS', '...  111130.33
# 148  ['Bancos de couro', 'Sensor de chuva', 'Ar con...   69219.89
# 149  ['Freios ABS', 'Teto panorâmico', 'Central mul...  144118.91
# 157  ['Ar condicionado', 'Sensor de estacionamento'...  132662.32
# 173  ['Ar condicionado', 'Sensor de estacionamento'...   85311.40
# 189  ['Travas elétricas', 'Controle de tração', 'Câ...   97290.18
# 208  ['Piloto automático', 'Teto panorâmico', 'Câmb...  112350.61
# 210  ['Controle de tração', 'Ar condicionado', 'Tra...   54263.16
# 211  ['Controle de tração', 'Piloto automático', 'T...   62041.32
# 226  ['Controle de tração', 'Sensor de estacionamen...  141083.35
# 233  ['Sensor de chuva', 'Vidros elétricos', 'Contr...   73311.75
# 237  ['Vidros elétricos', 'Travas elétricas', 'Roda...   67539.79
# 240  ['Rodas de liga', 'Sensor crepuscular', 'Ar co...  114728.74
# 256  ['Ar condicionado', '4 X 4', 'Câmbio automátic...  122110.90

# %%
type(filtro)
# Out:
# pandas.core.series.Series

# %%
df = dataset[filtro]
df
# Out:
#                       Nome         Motor   Ano  Quilometragem  Zero_km  \
# 1                   Passat  Motor Diesel  1991         5712.0    False
# 23   Effa Hafei Picape Baú  Motor Diesel  1991       102959.0    False
# 60                 Sorento  Motor Diesel  2019            NaN     True
# 62        New Fiesta Hatch  Motor Diesel  2017       118895.0    False
# 69          Kangoo Express  Motor Diesel  2007        29132.0    False
# 74                     Fit  Motor Diesel  2013        44329.0    False
# 78             Cielo Hatch  Motor Diesel  2019            NaN     True
# 86                  Symbol  Motor Diesel  2016       117714.0    False
# 89                A4 Sedan  Motor Diesel  2002        30511.0    False
# 111               A4 Avant  Motor Diesel  2014        17357.0    False
# 119          Silver Shadow  Motor Diesel  2015        99052.0    False
# 124                  Camry  Motor Diesel  2019            NaN     True
# 145                   Clio  Motor Diesel  1990        66437.0    False
# 148       Série 3 M3 Coupé  Motor Diesel  2013        19896.0    False
# 149    Gallardo LP 560 – 4  Motor Diesel  2000       113045.0    False
# 157          Chana Utility  Motor Diesel  2009        52034.0    False
# 173            TT Roadster  Motor Diesel  1998       107392.0    False
# 189    Aston Martin Virage  Motor Diesel  2019            NaN     True
# 208                Sandero  Motor Diesel  2015        34783.0    False
# 210                    XKR  Motor Diesel  1996        85127.0    False
# 211                     X5  Motor Diesel  2002        13606.0    False
# 226           Dodge Dakota  Motor Diesel  1993        71544.0    False
# 233                 i30 CW  Motor Diesel  2015         8497.0    False
# 237           Série 7 Sedã  Motor Diesel  2019            NaN     True
# 240                    V60  Motor Diesel  2004        91840.0    False
# 256       Aston Martin DB5  Motor Diesel  1996         7685.0    False
#
#                                             Acessórios      Valor
# 1    ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94
# 23   ['Controle de estabilidade', 'Painel digital',...  125684.65
# 60   ['Sensor de chuva', 'Câmera de estacionamento'...   81399.35
# 62   ['Sensor de estacionamento', 'Travas elétricas...   66007.16
# 69   ['Bancos de couro', 'Câmbio automático', 'Pilo...  146716.91
# 74   ['Freios ABS', 'Câmera de estacionamento', 'Câ...   77836.23
# 78   ['Painel digital', 'Central multimídia', 'Câme...  145197.70
# 86   ['4 X 4', 'Piloto automático', 'Sensor crepusc...  133030.60
# 89   ['Câmera de estacionamento', '4 X 4', 'Travas ...   96369.04
# 111  ['Teto panorâmico', '4 X 4', 'Bancos de couro'...  138946.88
# 119  ['4 X 4', 'Central multimídia', 'Ar condiciona...  143568.22
# 124  ['Travas elétricas', 'Rodas de liga', 'Sensor ...  138597.27
# 145  ['4 X 4', 'Câmbio automático', 'Freios ABS', '...  111130.33
# 148  ['Bancos de couro', 'Sensor de chuva', 'Ar con...   69219.89
# 149  ['Freios ABS', 'Teto panorâmico', 'Central mul...  144118.91
# 157  ['Ar condicionado', 'Sensor de estacionamento'...  132662.32
# 173  ['Ar condicionado', 'Sensor de estacionamento'...   85311.40
# 189  ['Travas elétricas', 'Controle de tração', 'Câ...   97290.18
# 208  ['Piloto automático', 'Teto panorâmico', 'Câmb...  112350.61
# 210  ['Controle de tração', 'Ar condicionado', 'Tra...   54263.16
# 211  ['Controle de tração', 'Piloto automático', 'T...   62041.32
# 226  ['Controle de tração', 'Sensor de estacionamen...  141083.35
# 233  ['Sensor de chuva', 'Vidros elétricos', 'Contr...   73311.75
# 237  ['Vidros elétricos', 'Travas elétricas', 'Roda...   67539.79
# 240  ['Rodas de liga', 'Sensor crepuscular', 'Ar co...  114728.74
# 256  ['Ar condicionado', '4 X 4', 'Câmbio automátic...  122110.90

# %%
filtro = (dataset.Motor == 'Motor Diesel')|(dataset.Zero_km == True)
dataset[filtro].info()
dataset[filtro]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 82 entries, 1 to 256
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Nome           82 non-null     object
#  1   Motor          82 non-null     object
#  2   Ano            82 non-null     int64
#  3   Quilometragem  21 non-null     float64
#  4   Zero_km        82 non-null     bool
#  5   Acessórios     82 non-null     object
#  6   Valor          82 non-null     float64
# dtypes: bool(1), float64(2), int64(1), object(3)
# memory usage: 4.6+ KB
#                  Nome            Motor   Ano  Quilometragem  Zero_km  \
# 1              Passat     Motor Diesel  1991         5712.0    False
# 3                 DS5  Motor 2.4 Turbo  2019            NaN     True
# 6                  A5  Motor 4.0 Turbo  2019            NaN     True
# 13                 J5         Motor V6  2019            NaN     True
# 17                 A3     Motor 1.0 8v  2019            NaN     True
# ..                ...              ...   ...            ...      ...
# 242        Benni Mini         Motor V8  2019            NaN     True
# 243               Uno  Motor Diesel V6  2019            NaN     True
# 245          Santa Fe    Motor 3.0 32v  2019            NaN     True
# 248              XC60  Motor 4.0 Turbo  2019            NaN     True
# 256  Aston Martin DB5     Motor Diesel  1996         7685.0    False
#
#                                             Acessórios      Valor
# 1    ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94
# 3    ['Travas elétricas', '4 X 4', 'Vidros elétrico...  124549.07
# 6    ['Câmbio automático', 'Câmera de estacionament...   56445.20
# 13   ['Sensor crepuscular', 'Painel digital', 'Roda...   53183.38
# 17   ['4 X 4', 'Piloto automático', 'Central multim...   88552.39
# ..                                                 ...        ...
# 242  ['Sensor crepuscular', 'Câmbio automático', 'C...  126247.84
# 243  ['Central multimídia', 'Sensor crepuscular', '...  128852.21
# 245  ['Travas elétricas', 'Ar condicionado', '4 X 4...  129415.33
# 248  ['Painel digital', 'Piloto automático', 'Centr...   77675.79
# 256  ['Ar condicionado', '4 X 4', 'Câmbio automátic...  122110.90
#
# [82 rows x 7 columns]

# %%
filtro2 = (dataset.Motor == 'Motor Diesel')&(dataset.Zero_km == True)&(dataset.Valor <= 70000)
filtro2
dataset[filtro2]
# Out:
#              Nome         Motor   Ano  Quilometragem  Zero_km  \
# 237  Série 7 Sedã  Motor Diesel  2019            NaN     True
#
#                                             Acessórios     Valor
# 237  ['Vidros elétricos', 'Travas elétricas', 'Roda...  67539.79

# %% [markdown]
# Utilizando o método Query

# %% [markdown]
# query('Regra lógica')

# %%
df = dataset.query('Motor == "Motor Diesel" and Ano >= 2013 and Valor > 100000')
df
# Out:
#               Nome         Motor   Ano  Quilometragem  Zero_km  \
# 78     Cielo Hatch  Motor Diesel  2019            NaN     True
# 86          Symbol  Motor Diesel  2016       117714.0    False
# 111       A4 Avant  Motor Diesel  2014        17357.0    False
# 119  Silver Shadow  Motor Diesel  2015        99052.0    False
# 124          Camry  Motor Diesel  2019            NaN     True
# 208        Sandero  Motor Diesel  2015        34783.0    False
#
#                                             Acessórios      Valor
# 78   ['Painel digital', 'Central multimídia', 'Câme...  145197.70
# 86   ['4 X 4', 'Piloto automático', 'Sensor crepusc...  133030.60
# 111  ['Teto panorâmico', '4 X 4', 'Bancos de couro'...  138946.88
# 119  ['4 X 4', 'Central multimídia', 'Ar condiciona...  143568.22
# 124  ['Travas elétricas', 'Rodas de liga', 'Sensor ...  138597.27
# 208  ['Piloto automático', 'Teto panorâmico', 'Câmb...  112350.61

# %% [markdown]
# # Iterando com DataFrames

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.set_option.html

# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv('https://raw.githubusercontent.com/daniel-usp/LIT/master/db.csv' , sep = ';')

# %%
dataset.head()
# Out:
#                Nome            Motor   Ano  Quilometragem  Zero_km  \
# 0     Jetta Variant  Motor 4.0 Turbo  2003        44410.0    False
# 1            Passat     Motor Diesel  1991         5712.0    False
# 2          Crossfox  Motor Diesel V8  1990        37123.0    False
# 3               DS5  Motor 2.4 Turbo  2019            NaN     True
# 4  Aston Martin DB4  Motor 2.4 Turbo  2006        25757.0    False
#
#                                           Acessórios      Valor
# 0  ['Rodas de liga', 'Travas elétricas', 'Piloto ...   88078.64
# 1  ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94
# 2  ['Piloto automático', 'Controle de estabilidad...   72832.16
# 3  ['Travas elétricas', '4 X 4', 'Vidros elétrico...  124549.07
# 4  ['Rodas de liga', '4 X 4', 'Central multimídia...   92612.10

# %%
dataset['km_média'] = (dataset.Quilometragem) + 10000
dataset.head(5)
# Out:
#                Nome            Motor   Ano  Quilometragem  Zero_km  \
# 0     Jetta Variant  Motor 4.0 Turbo  2003        44410.0    False
# 1            Passat     Motor Diesel  1991         5712.0    False
# 2          Crossfox  Motor Diesel V8  1990        37123.0    False
# 3               DS5  Motor 2.4 Turbo  2019            NaN     True
# 4  Aston Martin DB4  Motor 2.4 Turbo  2006        25757.0    False
#
#                                           Acessórios      Valor  km_média
# 0  ['Rodas de liga', 'Travas elétricas', 'Piloto ...   88078.64   54410.0
# 1  ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94   15712.0
# 2  ['Piloto automático', 'Controle de estabilidad...   72832.16   47123.0
# 3  ['Travas elétricas', '4 X 4', 'Vidros elétrico...  124549.07       NaN
# 4  ['Rodas de liga', '4 X 4', 'Central multimídia...   92612.10   35757.0

# %%
dataset['km_média'] = (dataset.Quilometragem/(2019-dataset.Ano)).fillna(0)
dataset
# Out:
#                       Nome                  Motor   Ano  Quilometragem  \
# 0            Jetta Variant        Motor 4.0 Turbo  2003        44410.0
# 1                   Passat           Motor Diesel  1991         5712.0
# 2                 Crossfox        Motor Diesel V8  1990        37123.0
# 3                      DS5        Motor 2.4 Turbo  2019            NaN
# 4         Aston Martin DB4        Motor 2.4 Turbo  2006        25757.0
# ..                     ...                    ...   ...            ...
# 253           Phantom 2013               Motor V8  2014        27505.0
# 254  Cadillac Ciel concept               Motor V8  1991        29981.0
# 255             Classe GLK  Motor 5.0 V8 Bi-Turbo  2002        52637.0
# 256       Aston Martin DB5           Motor Diesel  1996         7685.0
# 257                  Macan        Motor Diesel V6  1992        50188.0
#
#      Zero_km                                         Acessórios      Valor  \
# 0      False  ['Rodas de liga', 'Travas elétricas', 'Piloto ...   88078.64
# 1      False  ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94
# 2      False  ['Piloto automático', 'Controle de estabilidad...   72832.16
# 3       True  ['Travas elétricas', '4 X 4', 'Vidros elétrico...  124549.07
# 4      False  ['Rodas de liga', '4 X 4', 'Central multimídia...   92612.10
# ..       ...                                                ...        ...
# 253    False  ['Controle de estabilidade', 'Piloto automátic...   51759.58
# 254    False  ['Bancos de couro', 'Painel digital', 'Sensor ...   51667.06
# 255    False  ['Rodas de liga', 'Controle de tração', 'Câmbi...   68934.03
# 256    False  ['Ar condicionado', '4 X 4', 'Câmbio automátic...  122110.90
# 257    False  ['Central multimídia', 'Teto panorâmico', 'Vid...   90381.47
#
#         km_média
# 0    2775.625000
# 1     204.000000
# 2    1280.103448
# 3       0.000000
# 4    1981.307692
# ..           ...
# 253  5501.000000
# 254  1070.750000
# 255  3096.294118
# 256   334.130435
# 257  1858.814815
#
# [258 rows x 8 columns]

# %%
dataset.head()
# Out:
#                Nome            Motor   Ano  Quilometragem  Zero_km  \
# 0     Jetta Variant  Motor 4.0 Turbo  2003        44410.0    False
# 1            Passat     Motor Diesel  1991         5712.0    False
# 2          Crossfox  Motor Diesel V8  1990        37123.0    False
# 3               DS5  Motor 2.4 Turbo  2019            NaN     True
# 4  Aston Martin DB4  Motor 2.4 Turbo  2006        25757.0    False
#
#                                           Acessórios      Valor     km_média
# 0  ['Rodas de liga', 'Travas elétricas', 'Piloto ...   88078.64  2775.625000
# 1  ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94   204.000000
# 2  ['Piloto automático', 'Controle de estabilidad...   72832.16  1280.103448
# 3  ['Travas elétricas', '4 X 4', 'Vidros elétrico...  124549.07     0.000000
# 4  ['Rodas de liga', '4 X 4', 'Central multimídia...   92612.10  1981.307692

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 258 entries, 0 to 257
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Nome           258 non-null    object
#  1   Motor          258 non-null    object
#  2   Ano            258 non-null    int64
#  3   Quilometragem  197 non-null    float64
#  4   Zero_km        258 non-null    bool
#  5   Acessórios     258 non-null    object
#  6   Valor          258 non-null    float64
#  7   km_média       258 non-null    float64
# dtypes: bool(1), float64(3), int64(1), object(3)
# memory usage: 14.5+ KB

# %%
dataset['Quilometragem'].isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 253    False
# 254    False
# 255    False
# 256    False
# 257    False
# Name: Quilometragem, Length: 258, dtype: bool

# %%
len(dataset['Quilometragem'].isna())
# Out:
# 258

# %%
filtro = dataset['Quilometragem'].isna()
dataset[filtro]
# Out:
#                      Nome            Motor   Ano  Quilometragem  Zero_km  \
# 3                     DS5  Motor 2.4 Turbo  2019            NaN     True
# 6                      A5  Motor 4.0 Turbo  2019            NaN     True
# 13                     J5         Motor V6  2019            NaN     True
# 17                     A3     Motor 1.0 8v  2019            NaN     True
# 21              Série 1 M         Motor V8  2019            NaN     True
# ..                    ...              ...   ...            ...      ...
# 238  Lamborghini Reventón  Motor 4.0 Turbo  2019            NaN     True
# 242            Benni Mini         Motor V8  2019            NaN     True
# 243                   Uno  Motor Diesel V6  2019            NaN     True
# 245              Santa Fe    Motor 3.0 32v  2019            NaN     True
# 248                  XC60  Motor 4.0 Turbo  2019            NaN     True
#
#                                             Acessórios      Valor  km_média
# 3    ['Travas elétricas', '4 X 4', 'Vidros elétrico...  124549.07       0.0
# 6    ['Câmbio automático', 'Câmera de estacionament...   56445.20       0.0
# 13   ['Sensor crepuscular', 'Painel digital', 'Roda...   53183.38       0.0
# 17   ['4 X 4', 'Piloto automático', 'Central multim...   88552.39       0.0
# 21   ['Controle de estabilidade', 'Central multimíd...   94564.40       0.0
# ..                                                 ...        ...       ...
# 238  ['Controle de tração', 'Ar condicionado', 'Cen...   67664.86       0.0
# 242  ['Sensor crepuscular', 'Câmbio automático', 'C...  126247.84       0.0
# 243  ['Central multimídia', 'Sensor crepuscular', '...  128852.21       0.0
# 245  ['Travas elétricas', 'Ar condicionado', '4 X 4...  129415.33       0.0
# 248  ['Painel digital', 'Piloto automático', 'Centr...   77675.79       0.0
#
# [61 rows x 8 columns]

# %%
dataset.fillna(0, inplace = True)
dataset
# Out:
#                       Nome                  Motor   Ano  Quilometragem  \
# 0            Jetta Variant        Motor 4.0 Turbo  2003        44410.0
# 1                   Passat           Motor Diesel  1991         5712.0
# 2                 Crossfox        Motor Diesel V8  1990        37123.0
# 3                      DS5        Motor 2.4 Turbo  2019            0.0
# 4         Aston Martin DB4        Motor 2.4 Turbo  2006        25757.0
# ..                     ...                    ...   ...            ...
# 253           Phantom 2013               Motor V8  2014        27505.0
# 254  Cadillac Ciel concept               Motor V8  1991        29981.0
# 255             Classe GLK  Motor 5.0 V8 Bi-Turbo  2002        52637.0
# 256       Aston Martin DB5           Motor Diesel  1996         7685.0
# 257                  Macan        Motor Diesel V6  1992        50188.0
#
#      Zero_km                                         Acessórios      Valor  \
# 0      False  ['Rodas de liga', 'Travas elétricas', 'Piloto ...   88078.64
# 1      False  ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94
# 2      False  ['Piloto automático', 'Controle de estabilidad...   72832.16
# 3       True  ['Travas elétricas', '4 X 4', 'Vidros elétrico...  124549.07
# 4      False  ['Rodas de liga', '4 X 4', 'Central multimídia...   92612.10
# ..       ...                                                ...        ...
# 253    False  ['Controle de estabilidade', 'Piloto automátic...   51759.58
# 254    False  ['Bancos de couro', 'Painel digital', 'Sensor ...   51667.06
# 255    False  ['Rodas de liga', 'Controle de tração', 'Câmbi...   68934.03
# 256    False  ['Ar condicionado', '4 X 4', 'Câmbio automátic...  122110.90
# 257    False  ['Central multimídia', 'Teto panorâmico', 'Vid...   90381.47
#
#         km_média
# 0    2775.625000
# 1     204.000000
# 2    1280.103448
# 3       0.000000
# 4    1981.307692
# ..           ...
# 253  5501.000000
# 254  1070.750000
# 255  3096.294118
# 256   334.130435
# 257  1858.814815
#
# [258 rows x 8 columns]

# %%
dataset_ordem_decrescente_valor = dataset.sort_values(by = "Valor", ascending= False)
dataset_ordem_decrescente_valor
# Out:
#                       Nome                  Motor   Ano  Quilometragem  \
# 128                    ASX        Motor Diesel V8  2003        61672.0
# 117  Lamborghini Ferruccio          Motor 3.0 32v  2019            0.0
# 142                 Voyage  Motor 5.0 V8 Bi-Turbo  2019            0.0
# 50                   Versa          Motor 3.0 32v  2009        85554.0
# 132    Aston Martin Cygnet  Motor 5.0 V8 Bi-Turbo  2019            0.0
# ..                     ...                    ...   ...            ...
# 82      Cadillac XTS sedan        Motor Diesel V6  1993        90924.0
# 253           Phantom 2013               Motor V8  2014        27505.0
# 254  Cadillac Ciel concept               Motor V8  1991        29981.0
# 36              Pajero TR4        Motor 2.4 Turbo  2019            0.0
# 79                  Livina          Motor 2.0 16v  2019            0.0
#
#      Zero_km                                         Acessórios      Valor  \
# 128    False  ['Ar condicionado', 'Sensor crepuscular', 'Rod...  149489.92
# 117     True  ['Vidros elétricos', 'Piloto automático', 'Tet...  149157.17
# 142     True  ['Ar condicionado', 'Sensor de estacionamento'...  148996.47
# 50     False  ['Bancos de couro', 'Ar condicionado', 'Rodas ...  148152.89
# 132     True  ['Painel digital', 'Ar condicionado', 'Sensor ...  147770.87
# ..       ...                                                ...        ...
# 82     False  ['Ar condicionado', 'Câmbio automático', 'Sens...   52207.45
# 253    False  ['Controle de estabilidade', 'Piloto automátic...   51759.58
# 254    False  ['Bancos de couro', 'Painel digital', 'Sensor ...   51667.06
# 36      True  ['Controle de tração', 'Bancos de couro', 'Câm...   51606.59
# 79      True  ['Sensor crepuscular', 'Câmera de estacionamen...   50742.10
#
#         km_média
# 128  3854.500000
# 117     0.000000
# 142     0.000000
# 50   8555.400000
# 132     0.000000
# ..           ...
# 82   3497.076923
# 253  5501.000000
# 254  1070.750000
# 36      0.000000
# 79      0.000000
#
# [258 rows x 8 columns]

# %%
dataset.groupby(by = ["Motor"])["Valor"].describe().sort_values(by = "mean", ascending = False)
# Out:
#                        count           mean           std       min  \
# Motor
# Motor V6                20.0  107471.725000  29111.613498  53183.38
# Motor Diesel            26.0  107179.946154  30813.581942  54263.16
# Motor Diesel V6         21.0  104054.461429  28998.298716  52207.45
# Motor Diesel V8         21.0  103580.674762  32250.478003  56646.34
# Motor 4.0 Turbo         25.0  102303.932000  25428.616630  56445.20
# Motor 2.4 Turbo         10.0   99104.985000  23525.476369  51606.59
# Motor V8                26.0   97934.818846  32497.832809  51667.06
# Motor 1.0 8v            25.0   97832.979200  30296.841182  52805.91
# Motor 2.0 16v           18.0   94041.291111  31635.837861  50742.10
# Motor 3.0 32v           27.0   93772.808148  29392.259753  53620.31
# Motor 5.0 V8 Bi-Turbo   21.0   93346.201905  34345.805591  56208.70
# Motor 1.8 16v           18.0   83872.455556  22348.225978  53894.61
#
#                               25%         50%          75%        max
# Motor
# Motor V6               89256.7500  112439.895  130329.4950  141982.93
# Motor Diesel           78727.0100  111740.470  137205.6025  146716.91
# Motor Diesel V6        77397.0500  113090.320  125398.1100  147627.81
# Motor Diesel V8        73919.5300  102968.760  135543.0000  149489.92
# Motor 4.0 Turbo        88078.6400  106617.710  120812.5700  146405.79
# Motor 2.4 Turbo        83470.0575  101660.995  119568.9350  124549.07
# Motor V8               62969.3900  104935.450  127419.5050  139661.48
# Motor 1.0 8v           70424.1100   97951.030  123911.7800  146203.34
# Motor 2.0 16v          68707.5675   81882.390  119520.6325  142623.02
# Motor 3.0 32v          66925.2850   96065.380  116870.3550  149157.17
# Motor 5.0 V8 Bi-Turbo  66433.8200   73033.530  127488.4200  148996.47
# Motor 1.8 16v          64179.3625   85638.180   97991.6950  129296.11

# %%
dataset.groupby(by = ["Ano"])["Quilometragem"].describe().sort_values(by = "mean", ascending = False)
# Out:
#       count          mean           std      min       25%       50%  \
# Ano
# 2000    3.0  98921.000000  27064.736854  67716.0  90380.50  113045.0
# 2010    6.0  79227.333333  22930.610054  35345.0  77572.50   86622.0
# 2017    7.0  74888.000000  48071.226987  10821.0  33884.50   96005.0
# 1990    6.0  72083.666667  31410.433411  37123.0  53425.25   60863.0
# 1997    6.0  71897.000000  33835.933473  30163.0  44722.25   75247.5
# 1998    3.0  71828.000000  38087.691201  31639.0  54046.00   76453.0
# 1995    7.0  71289.714286  30227.959043  42733.0  46941.00   53332.0
# 1994    9.0  70260.777778  34485.285883  23802.0  33659.00   81007.0
# 2001    8.0  69583.750000  34532.656849   2395.0  52757.00   79848.5
# 2004    5.0  62735.800000  21207.677541  33215.0  57683.00   60996.0
# 2008    6.0  61647.833333  49992.483113    610.0  19376.75   69131.0
# 2015    8.0  61032.125000  39235.030552   8497.0  31668.00   60651.0
# 2007   12.0  59986.750000  37302.653503   8052.0  25408.25   67800.0
# 2002   11.0  59268.545455  38230.154034   9755.0  22058.50   58848.0
# 2005    6.0  58052.500000  31045.693600  35647.0  42388.25   49080.0
# 2014    6.0  57461.500000  39520.219133  17357.0  26008.75   49601.0
# 2003    7.0  56926.571429  33072.504712   4539.0  42586.00   56638.0
# 1993    8.0  55384.250000  32970.490030   6652.0  30237.25   55082.0
# 2011    5.0  53031.000000  36539.169976  15987.0  37978.00   48509.0
# 1992    4.0  51283.000000  17543.536493  32555.0  43766.00   48845.5
# 1996   10.0  50926.100000  39012.405174   3173.0  10505.00   56810.0
# 2016    8.0  49972.000000  45575.209963   5795.0  17335.00   31649.0
# 2009    7.0  48694.000000  28890.634197   5526.0  30966.50   52034.0
# 1991    9.0  47036.444444  45012.186931    107.0   8394.00   32056.0
# 2006    8.0  45569.750000  32820.897153   8849.0  21716.50   38613.5
# 2012    4.0  40817.500000  41089.034259   9293.0  10369.25   28588.5
# 1999    4.0  39075.500000  32169.396311  12887.0  13756.25   31614.0
# 2013    9.0  39021.777778  34098.264772   2314.0  15196.00   24638.0
# 2018    5.0  31999.000000  32266.834149   9146.0  17720.00   17924.0
# 2019   61.0      0.000000      0.000000      0.0      0.00       0.0
#
#             75%       max
# Ano
# 2000  114523.50  116002.0
# 2010   91422.00   99197.0
# 2017  114930.50  119760.0
# 1990   94534.25  116949.0
# 1997   99793.75  108201.0
# 1998   91922.50  107392.0
# 1995   99258.50  110564.0
# 1994   98079.00  118236.0
# 2001   92557.75  104341.0
# 2004   69945.00   91840.0
# 2008  103094.00  113808.0
# 2015   93220.75  109001.0
# 2007   85090.00  119513.0
# 2002   89013.00  114942.0
# 2005   53074.00  119945.0
# 2014   85937.25  112016.0
# 2003   71010.50  110116.0
# 1993   87529.25   90924.0
# 2011   48796.00  113885.0
# 1992   56362.50   74886.0
# 1996   84748.00   96610.0
# 2016   80410.25  117714.0
# 2009   67905.50   85554.0
# 1991   94381.00  115930.0
# 2006   71033.25   93947.0
# 2012   59036.75   96800.0
# 1999   56933.25   80187.0
# 2013   73914.00   93415.0
# 2018   26544.00   88661.0
# 2019       0.00       0.0
